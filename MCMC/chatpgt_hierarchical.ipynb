# %%
import torch
import pyro
import pyro.distributions as dist
from pyro.infer import MCMC, NUTS

# Generate synthetic data
num_groups = 3
group_sizes = [5, 6, 4]
data = [torch.randn(size) for size in group_sizes]

# Define the hierarchical model
def hierarchical_model(data):
    # Prior for group-level parameters
    group_mean = pyro.sample("group_mean", dist.Normal(0, 1))
    group_std = pyro.sample("group_std", dist.Exponential(1))

    # Model for individual data points within groups
    with pyro.plate("data_plate", len(data)):
        for i, group_data in enumerate(data):
            # Prior for individual-level parameters (conditional on group-level parameters)
            mean = pyro.sample(f"mean_{i}", dist.Normal(group_mean, group_std))
            std = pyro.sample(f"std_{i}", dist.Exponential(1))
            
            # Likelihood
            pyro.sample(f"obs_{i}", dist.Normal(mean, std), obs=group_data)

# Run MCMC inference
nuts_kernel = NUTS(hierarchical_model)
mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)
mcmc.run(data)

# Get posterior samples
posterior_samples = mcmc.get_samples()

# Print posterior statistics
for param_name, samples in posterior_samples.items():
    print(f"Parameter: {param_name}")
    print(f"Mean: {torch.mean(samples, dim=0)}")
    print(f"Std: {torch.std(samples, dim=0)}")
    print()
# Out:
# Warmup:   0%|                                                                | 0/1200 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 30
#      28 nuts_kernel = NUTS(hierarchical_model)
#      29 mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)
# ---> 30 mcmc.run(data)
#      32 # Get posterior samples
#      33 posterior_samples = mcmc.get_samples()
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:563, in MCMC.run(self, *args, **kwargs)
#     554 with optional(
#     555     pyro.validation_enabled(not self.disable_validation),
#     556     self.disable_validation is not None,
#    (...)
#     560     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     561     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     562     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 563     for x, chain_id in self.sampler.run(*args, **kwargs):
#     564         if num_samples[chain_id] == 0:
#     565             num_samples[chain_id] += 1
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:223, in _UnarySampler.run(self, *args, **kwargs)
#     221 logger = initialize_logger(logger, "", progress_bar)
#     222 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 223 for sample in _gen_samples(
#     224     self.kernel,
#     225     self.warmup_steps,
#     226     self.num_samples,
#     227     hook_w_logging,
#     228     i if self.num_chains > 1 else None,
#     229     *args,
#     230     **kwargs
#     231 ):
#     232     yield sample, i  # sample, chain_id
#     233 self.kernel.cleanup()
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:144, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     143 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 144     kernel.setup(warmup_steps, *args, **kwargs)
#     145     params = kernel.initial_params
#     146     save_params = getattr(kernel, "save_params", sorted(params))
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/hmc.py:345, in HMC.setup(self, warmup_steps, *args, **kwargs)
#     343 self._warmup_steps = warmup_steps
#     344 if self.model is not None:
# --> 345     self._initialize_model_properties(args, kwargs)
#     346 if self.initial_params:
#     347     z = {k: v.detach() for k, v in self.initial_params.items()}
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/hmc.py:279, in HMC._initialize_model_properties(self, model_args, model_kwargs)
#     278 def _initialize_model_properties(self, model_args, model_kwargs):
# --> 279     init_params, potential_fn, transforms, trace = initialize_model(
#     280         self.model,
#     281         model_args,
#     282         model_kwargs,
#     283         transforms=self.transforms,
#     284         max_plate_nesting=self._max_plate_nesting,
#     285         jit_compile=self._jit_compile,
#     286         jit_options=self._jit_options,
#     287         skip_jit_warnings=self._ignore_jit_warnings,
#     288         init_strategy=self._init_strategy,
#     289         initial_params=self._initial_params,
#     290     )
#     291     self.potential_fn = potential_fn
#     292     self.transforms = transforms
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:468, in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     464     prototype_params = {k: transforms[k](v) for k, v in prototype_samples.items()}
#     465     # Note that we deliberately do not exercise jit compilation here so as to
#     466     # enable potential_fn to be picklable (a torch._C.Function cannot be pickled).
#     467     # We pass model_trace merely for computational savings.
# --> 468     initial_params = _find_valid_initial_params(
#     469         model,
#     470         model_args,
#     471         model_kwargs,
#     472         transforms,
#     473         pe_maker.get_potential_fn(),
#     474         prototype_params,
#     475         num_chains=num_chains,
#     476         init_strategy=init_strategy,
#     477         trace=model_trace,
#     478     )
#     479 potential_fn = pe_maker.get_potential_fn(
#     480     jit_compile, skip_jit_warnings, jit_options
#     481 )
#     482 return initial_params, potential_fn, transforms, model_trace
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:351, in _find_valid_initial_params(model, model_args, model_kwargs, transforms, potential_fn, prototype_params, max_tries_initial_params, num_chains, init_strategy, trace)
#     349 samples = {name: trace.nodes[name]["value"].detach() for name in params}
#     350 params = {k: transforms[k](v) for k, v in samples.items()}
# --> 351 pe_grad, pe = potential_grad(potential_fn, params)
#     353 if torch.isfinite(pe) and all(
#     354     map(torch.all, map(torch.isfinite, pe_grad.values()))
#     355 ):
#     356     for k, v in params.items():
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/ops/integrator.py:90, in potential_grad(potential_fn, z)
#      88         return grads, z_nodes[0].new_tensor(float("nan"))
#      89     else:
# ---> 90         raise e
#      91 grads = grad(potential_energy, z_nodes)
#      92 for node in z_nodes:
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/ops/integrator.py:83, in potential_grad(potential_fn, z)
#      81     node.requires_grad_(True)
#      82 try:
# ---> 83     potential_energy = potential_fn(z)
#      84 # handle exceptions as defined in the exception registry
#      85 except Exception as e:
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:281, in _PEMaker._potential_fn(self, params)
#     277 cond_model = poutine.condition(self.model, params_constrained)
#     278 model_trace = poutine.trace(cond_model).get_trace(
#     279     *self.model_args, **self.model_kwargs
#     280 )
# --> 281 log_joint = self.trace_prob_evaluator.log_prob(model_trace)
#     282 for name, t in self.transforms.items():
#     283     log_joint = log_joint - torch.sum(
#     284         t.log_abs_det_jacobian(params_constrained[name], params[name])
#     285     )
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/infer/mcmc/util.py:238, in TraceEinsumEvaluator.log_prob(self, model_trace)
#     231 """
#     232 Returns the log pdf of `model_trace` by appropriately handling
#     233 enumerated log prob factors.
#     234
#     235 :return: log pdf of the trace.
#     236 """
#     237 if not self.has_enumerable_sites:
# --> 238     return model_trace.log_prob_sum()
#     239 log_probs = self._get_log_factors(model_trace)
#     240 with shared_intermediates() as cache:
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/pyro/poutine/trace_struct.py:196, in Trace.log_prob_sum(self, site_filter)
#     194 else:
#     195     try:
# --> 196         log_p = site["fn"].log_prob(
#     197             site["value"], *site["args"], **site["kwargs"]
#     198         )
#     199     except ValueError as e:
#     200         _, exc_value, traceback = sys.exc_info()
#
# File ~/Documents/python_env/pyro/lib/python3.11/site-packages/torch/distributions/normal.py:86, in Normal.log_prob(self, value)
#      81 var = self.scale**2
#      82 log_scale = (
#      83     math.log(self.scale) if isinstance(self.scale, Real) else self.scale.log()
#      84 )
#      85 return (
# ---> 86     -((value - self.loc) ** 2) / (2 * var)
#      87     - log_scale
#      88     - math.log(math.sqrt(2 * math.pi))
#      89 )
#
# RuntimeError: The size of tensor a (5) must match the size of tensor b (3) at non-singleton dimension 0
